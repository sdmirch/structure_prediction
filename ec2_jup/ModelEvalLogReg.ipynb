# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from matplotlib.lines import Line2D

from sklearn.externals import joblib
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import roc_curve, classification_report, roc_auc_score


# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# # Clean

# %%
df = pd.read_csv('data/feats_cleaned.csv')

# %%
columns = df.columns
feat_cols = []
for name in columns:
    if name != "structureProteinName" and name != "cellID"\
    and name != "save_feats_path" and name != "protein_label":
        feat_cols.append(name)

# %% [markdown]
# # Create labels

# %%
y = df.structureProteinName
y_factorize = y.factorize()

# %%
labels = y_factorize[1]
labels
# Out:
# Index(['Sec61 beta', 'Alpha tubulin', 'Fibrillarin', 'Desmoplakin', 'Lamin B1',
#        'Myosin IIB', 'Beta actin', 'Tom20', 'Alpha actinin', 'ZO1', 'ST6GAL1'],
#       dtype='object')

# %% [markdown]
# # Models: Each trained on each label

# %%
for i in range(len(labels)):
    
    # Binarize labels
    df['protein_label'] = np.where(df['structureProteinName']==labels[i],1,0)
    
    # Split to features and labels
    X_temp = df[feat_cols]
    y = df.protein_label

    # Normalize so coefficients can be compared
    min_max_scaler = MinMaxScaler()
    np_scaled = min_max_scaler.fit_transform(X_temp)
    df_normalized = pd.DataFrame(np_scaled)
    df_normalized.columns = feat_cols

    # Reset X to normalized features
    X = df_normalized

    # Test Train Split stratified so classes are balanced in split
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10, test_size=.2, stratify=y)

    # Fit logistic regression with l2 regularization
    logregl2 = LogisticRegression(penalty='l2')
    logregl2.fit(X_train, y_train)

    # Print label, classification report, and accuracy
    print(str(labels[i]))
    print(classification_report(y_true=y_test, y_pred=logregl2.predict(X_test)))
    print("Mean Accuracy: ", logregl2.score(X_test, y_test))
    
    # Look at coefficients
    coef_df = pd.DataFrame(np.transpose(logregl2.coef_))
    coefficients = pd.concat([pd.DataFrame(X.columns),coef_df], axis = 1)
    coefficients.columns = ['feature','coef_val']
    coefficients['coef_val_abs'] = coefficients.coef_val.abs()
    print(coefficients.sort_values('coef_val_abs',ascending=False)[0:10])
    print('\n\n')
# Out:
# Sec61 beta
#              precision    recall  f1-score   support
#
#           0       0.91      0.99      0.95      3973
#           1       0.25      0.02      0.04       386
#
# avg / total       0.85      0.91      0.87      4359
#
# Mean Accuracy:  0.9077770130763937
#                               feature  coef_val  coef_val_abs
# 1544          feat_cell_mt_distHist_3 -2.173125      2.173125
# 807               feat_cell_mt_edge_1  2.129585      2.129585
# 1543          feat_cell_mt_distHist_2 -1.766818      1.766818
# 778       feat_nuc_mt_region_hist_629 -1.764966      1.764966
# 33         feat_cell_region_median_px  1.673083      1.673083
# 458       feat_nuc_mt_region_hist_309  1.649154      1.649154
# 829   feat_cell_mt_edge_region_hist_2  1.648220      1.648220
# 1170     feat_cell_mt_region_hist_279 -1.542518      1.542518
# 1516     feat_cell_mt_region_hist_625  1.495484      1.495484
# 762       feat_nuc_mt_region_hist_613  1.455627      1.455627
#
#
#
# Alpha tubulin
#              precision    recall  f1-score   support
#
#           0       0.85      0.98      0.91      3664
#           1       0.43      0.09      0.15       695
#
# avg / total       0.78      0.84      0.79      4359
#
# Mean Accuracy:  0.836200963523744
#                              feature  coef_val  coef_val_abs
# 72                feat_nuc_mt_edge_8  2.493647      2.493647
# 822             feat_cell_mt_edge_16  2.249497      2.249497
# 1631          feat_cell_obj_eigval_3  2.161915      2.161915
# 1662         feat_nuc_obj_tot_height -2.041516      2.041516
# 300      feat_nuc_mt_region_hist_151  1.927966      1.927966
# 821             feat_cell_mt_edge_15  1.825849      1.825849
# 816             feat_cell_mt_edge_10 -1.797423      1.797423
# 6         feat_nuc_region_entropy_px -1.794374      1.794374
# 1549  feat_nuc_shape_MajorAxisLength -1.755092      1.755092
# 79               feat_nuc_mt_edge_15  1.738146      1.738146
#
#
#
# Fibrillarin
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      4161
#           1       0.38      0.09      0.15       198
#
# avg / total       0.93      0.95      0.94      4359
#
# Mean Accuracy:  0.9518238128011012
#                                  feature  coef_val  coef_val_abs
# 37               feat_cell_region_std_px  3.018109      3.018109
# 72                    feat_nuc_mt_edge_8 -2.266893      2.266893
# 828      feat_cell_mt_edge_region_hist_1  2.167809      2.167809
# 1543             feat_cell_mt_distHist_2 -1.994204      1.994204
# 881     feat_cell_mt_edge_region_hist_54  1.794720      1.794720
# 1544             feat_cell_mt_distHist_3 -1.739522      1.739522
# 65                    feat_nuc_mt_edge_1 -1.724534      1.724534
# 1584  feat_cell_polarity_cell_z_affinity -1.681847      1.681847
# 40       feat_cell_region_histogram_px_2  1.626898      1.626898
# 1538        feat_cell_mt_statDistLevel_1  1.593136      1.593136
#
#
#
# Desmoplakin
#              precision    recall  f1-score   support
#
#           0       0.89      0.99      0.93      3847
#           1       0.35      0.04      0.07       512
#
# avg / total       0.82      0.88      0.83      4359
#
# Mean Accuracy:  0.8784124799265887
#                                feature  coef_val  coef_val_abs
# 1662           feat_nuc_obj_tot_height  2.230474      2.230474
# 807                feat_cell_mt_edge_1 -1.919280      1.919280
# 874   feat_cell_mt_edge_region_hist_47 -1.729891      1.729891
# 37             feat_cell_region_std_px -1.724234      1.724234
# 1433      feat_cell_mt_region_hist_542 -1.569542      1.569542
# 1521      feat_cell_mt_region_hist_630 -1.510192      1.510192
# 491        feat_nuc_mt_region_hist_342 -1.420719      1.420719
# 218         feat_nuc_mt_region_hist_69 -1.402886      1.402886
# 375        feat_nuc_mt_region_hist_226  1.394511      1.394511
# 4               feat_nuc_region_max_px -1.353702      1.353702
#
#
#
# Lamin B1
#              precision    recall  f1-score   support
#
#           0       0.82      0.96      0.88      3466
#           1       0.55      0.18      0.27       893
#
# avg / total       0.76      0.80      0.76      4359
#
# Mean Accuracy:  0.8011011699931176
#                                     feature  coef_val  coef_val_abs
# 1632               feat_cell_obj_tot_height -2.976823      2.976823
# 821                    feat_cell_mt_edge_15 -2.692210      2.692210
# 65                       feat_nuc_mt_edge_1  2.603634      2.603634
# 1604               feat_cell_obj_mean_depth  2.268479      2.268479
# 39          feat_cell_region_histogram_px_1  1.895827      1.895827
# 1543                feat_cell_mt_distHist_2  1.869793      1.869793
# 36                  feat_cell_region_max_px -1.863205      1.863205
# 1592  feat_nuc_polarity_nuc_distal_affinity -1.791827      1.791827
# 72                       feat_nuc_mt_edge_8 -1.704394      1.704394
# 1565             feat_cell_shape_ConvexArea -1.673165      1.673165
#
#
#
# Myosin IIB
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      4328
#           1       0.00      0.00      0.00        31
#
# avg / total       0.99      0.99      0.99      4359
#
# Mean Accuracy:  0.9928882771277816
#                                  feature  coef_val  coef_val_abs
# 1582  feat_cell_polarity_cyto_z_affinity -2.024017      2.024017
# 834      feat_cell_mt_edge_region_hist_7 -1.931760      1.931760
# 835      feat_cell_mt_edge_region_hist_8 -1.860794      1.860794
# 1578             feat_nuc_fract_z_height  1.633931      1.633931
# 821                 feat_cell_mt_edge_15 -1.484677      1.484677
# 814                  feat_cell_mt_edge_8 -1.360995      1.360995
# 696          feat_nuc_mt_region_hist_547 -1.328249      1.328249
# 1584  feat_cell_polarity_cell_z_affinity -1.277198      1.277198
# 832      feat_cell_mt_edge_region_hist_5 -1.260456      1.260456
# 833      feat_cell_mt_edge_region_hist_6 -1.224995      1.224995
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Beta actin
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      4038
#           1       0.44      0.11      0.18       321
#
# avg / total       0.90      0.92      0.90      4359
#
# Mean Accuracy:  0.9240651525579261
#                               feature  coef_val  coef_val_abs
# 1632         feat_cell_obj_tot_height  3.118232      3.118232
# 6          feat_nuc_region_entropy_px  2.579308      2.579308
# 39    feat_cell_region_histogram_px_1 -1.852952      1.852952
# 834   feat_cell_mt_edge_region_hist_7 -1.801961      1.801961
# 69                 feat_nuc_mt_edge_5  1.787442      1.787442
# 1196     feat_cell_mt_region_hist_305 -1.610669      1.610669
# 913       feat_cell_mt_region_hist_22 -1.608959      1.608959
# 164        feat_nuc_mt_region_hist_15  1.536551      1.536551
# 1028     feat_cell_mt_region_hist_137 -1.446166      1.446166
# 903       feat_cell_mt_region_hist_12 -1.350788      1.350788
#
#
#
# Tom20
#              precision    recall  f1-score   support
#
#           0       0.81      0.96      0.88      3490
#           1       0.42      0.11      0.17       869
#
# avg / total       0.74      0.79      0.74      4359
#
# Mean Accuracy:  0.7930718054599679
#                                feature  coef_val  coef_val_abs
# 822               feat_cell_mt_edge_16 -2.774363      2.774363
# 72                  feat_nuc_mt_edge_8  2.709452      2.709452
# 880   feat_cell_mt_edge_region_hist_53 -1.982134      1.982134
# 38         feat_cell_region_entropy_px  1.982031      1.982031
# 321        feat_nuc_mt_region_hist_172  1.764930      1.764930
# 65                  feat_nuc_mt_edge_1 -1.745245      1.745245
# 99     feat_nuc_mt_edge_region_hist_14  1.610895      1.610895
# 1578           feat_nuc_fract_z_height -1.604612      1.604612
# 815                feat_cell_mt_edge_9 -1.590467      1.590467
# 33          feat_cell_region_median_px -1.588525      1.588525
#
#
#
# Alpha actinin
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      4260
#           1       0.40      0.19      0.26        99
#
# avg / total       0.97      0.98      0.97      4359
#
# Mean Accuracy:  0.975223675154852
#                               feature  coef_val  coef_val_abs
# 834   feat_cell_mt_edge_region_hist_7 -2.948487      2.948487
# 809               feat_cell_mt_edge_3  2.719075      2.719075
# 832   feat_cell_mt_edge_region_hist_5 -2.318765      2.318765
# 40    feat_cell_region_histogram_px_2 -2.237002      2.237002
# 869  feat_cell_mt_edge_region_hist_42  1.712171      1.712171
# 872  feat_cell_mt_edge_region_hist_45  1.657905      1.657905
# 835   feat_cell_mt_edge_region_hist_8 -1.656066      1.656066
# 39    feat_cell_region_histogram_px_1  1.590754      1.590754
# 41    feat_cell_region_histogram_px_3 -1.583845      1.583845
# 811               feat_cell_mt_edge_5 -1.522831      1.522831
#
#
#
# ZO1
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      4312
#           1       0.67      0.17      0.27        47
#
# avg / total       0.99      0.99      0.99      4359
#
# Mean Accuracy:  0.9901353521449874
#                                  feature  coef_val  coef_val_abs
# 1582  feat_cell_polarity_cyto_z_affinity -2.528260      2.528260
# 835      feat_cell_mt_edge_region_hist_8 -2.140744      2.140744
# 832      feat_cell_mt_edge_region_hist_5 -1.896160      1.896160
# 1583   feat_cell_polarity_nuc_z_affinity  1.611989      1.611989
# 834      feat_cell_mt_edge_region_hist_7 -1.586459      1.586459
# 1584  feat_cell_polarity_cell_z_affinity -1.583293      1.583293
# 4                 feat_nuc_region_max_px  1.501184      1.501184
# 6             feat_nuc_region_entropy_px  1.433825      1.433825
# 68                    feat_nuc_mt_edge_4 -1.368232      1.368232
# 824                 feat_cell_mt_edge_18 -1.311407      1.311407
#
#
#
# ST6GAL1
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      4050
#           1       0.58      0.16      0.24       309
#
# avg / total       0.91      0.93      0.91      4359
#
# Mean Accuracy:  0.9320945170910759
#                                     feature  coef_val  coef_val_abs
# 1592  feat_nuc_polarity_nuc_distal_affinity  3.351581      3.351581
# 821                    feat_cell_mt_edge_15  2.930825      2.930825
# 822                    feat_cell_mt_edge_16 -2.707104      2.707104
# 814                     feat_cell_mt_edge_8  2.422826      2.422826
# 38              feat_cell_region_entropy_px  2.186553      2.186553
# 39          feat_cell_region_histogram_px_1 -1.942143      1.942143
# 37                  feat_cell_region_std_px -1.935690      1.935690
# 834         feat_cell_mt_edge_region_hist_7  1.913085      1.913085
# 815                     feat_cell_mt_edge_9 -1.865876      1.865876
# 854        feat_cell_mt_edge_region_hist_27  1.727381      1.727381
